# %%
from qiskit_ibm_provider import IBMProvider
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel
from qiskit import QuantumCircuit, transpile

# %%
# Carregar a conta do IBM Q usando o token e obter os backends disponíveis
provider = IBMProvider(token='SEU TOKEN IBM AQUI')
backends = provider.backends()
print("Backends disponíveis:", backends)
# Out:
# Backends disponíveis: [<IBMBackend('ibm_kyoto')>, <IBMBackend('ibm_osaka')>, <IBMBackend('ibm_sherbrooke')>, <IBMBackend('ibm_brisbane')>]

# %%
# Obter o backend menos ocupado com capacidades de simulação
backend = provider.get_backend('ibm_osaka')
print("Backend selecionado:", backend)
# Out:
# Backend selecionado: <IBMBackend('ibm_osaka')>

# %%
# Obter propriedades do backend, incluindo taxas de erro
backend_properties = backend.properties()

# %%
# Exemplo de como imprimir as propriedades dos qubits, incluindo taxas de erro
for qubit, qubit_properties in enumerate(backend_properties.qubits):
    print(f"Qubit {qubit}:")
    for prop in qubit_properties:
        print(f"  {prop.name}: {prop.value} {prop.unit}")
# Out:
# Qubit 0:
#   T1: 403.80099165906023 us
#   T2: 238.70947425449114 us
#   frequency: 4.822506598383234 GHz
#   anharmonicity: -0.30896613792557315 GHz
#   readout_error: 0.023700000000000054
#   prob_meas0_prep1: 0.0238
#   prob_meas1_prep0: 0.023599999999999954
#   readout_length: 1400 ns
# Qubit 1:
#   T1: 374.26596933579464 us
#   T2: 363.4410478845319 us
#   frequency: 4.772692694535915 GHz
#   anharmonicity: -0.3102210761952548 GHz
#   readout_error: 0.009800000000000031
#   prob_meas0_prep1: 0.009399999999999964
#   prob_meas1_prep0: 0.0102
#   readout_length: 1400 ns
# Qubit 2:
#   T1: 238.41578909243643 us
#   T2: 188.89507569245632 us
#   frequency: 4.718299139844406 GHz
#   anharmonicity: -0.3104037776462388 GHz
#   readout_error: 0.056499999999999995
#   prob_meas0_prep1: 0.08499999999999996
#   prob_meas1_prep0: 0.028
#   readout_length: 1400 ns
# Qubit 3:
#   T1: 251.2445320193855 us
#   T2: 150.93963601166797 us
#   frequency: 4.8001509393841095 GHz
#   anharmonicity: -0.30888128433002476 GHz
#   readout_error: 0.0484
#   prob_meas0_prep1: 0.0338
#   prob_meas1_prep0: 0.06299999999999994
#   readout_length: 1400 ns
# Qubit 4:
#   T1: 308.0738644513941 us
#   T2: 59.62223094111701 us
#   frequency: 4.832841806853506 GHz
#   anharmonicity: -0.308629272986329 GHz
#   readout_error: 0.2783333333333333
#   prob_meas0_prep1: 0.23
#   prob_meas1_prep0: 0.32666666666666666
#   readout_length: 1400 ns
# Qubit 5:
#   T1: 192.81547200617842 us
#   T2: 140.5127621089676 us
#   frequency: 4.660665155255208 GHz
#   anharmonicity: -0.31065594686359554 GHz
#   readout_error: 0.09666666666666668
#   prob_meas0_prep1: 0.09
#   prob_meas1_prep0: 0.10333333333333339
#   readout_length: 1400 ns
# Qubit 6:
#   T1: 316.58262939486445 us
#   T2: 49.1996741413632 us
#   frequency: 4.906930438111268 GHz
#   anharmonicity: -0.3068148235588046 GHz
#   readout_error: 0.035599999999999965
#   prob_meas0_prep1: 0.035599999999999965
#   prob_meas1_prep0: 0.0356
#   readout_length: 1400 ns
# Qubit 7:
#   T1: 358.7364713870208 us
#   T2: 8.693529524603012 us
#   frequency: 4.719547368893058 GHz
#   anharmonicity: -0.31037202891110505 GHz
#   readout_error: 0.03980000000000006
#   prob_meas0_prep1: 0.0192
#   prob_meas1_prep0: 0.06040000000000001
#   readout_length: 1400 ns
# Qubit 8:
#   T1: 205.09755521032278 us
#   T2: 8.22110143641713 us
#   frequency: 4.635379364719242 GHz
#   anharmonicity: -0.28702409316453614 GHz
#   readout_error: 0.16169999999999995
#   prob_meas0_prep1: 0.0956
#   prob_meas1_prep0: 0.2278
#   readout_length: 1400 ns
# Qubit 9:
#   T1: 433.38847349269116 us
#   T2: 77.79653533852857 us
#   frequency: 4.716763346909025 GHz
#   anharmonicity: -0.3104073125859284 GHz
#   readout_error: 0.031200000000000006
#   prob_meas0_prep1: 0.013399999999999967
#   prob_meas1_prep0: 0.049
#   readout_length: 1400 ns
# Qubit 10:
#   T1: 350.4426256656358 us
#   T2: 27.810319257752912 us
#   frequency: 4.669417765594935 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.0746
#   prob_meas0_prep1: 0.0936
#   prob_meas1_prep0: 0.05559999999999998
#   readout_length: 1400 ns
# Qubit 11:
#   T1: 348.50843750967107 us
#   T2: 473.9084695413049 us
#   frequency: 4.7252936214526 GHz
#   anharmonicity: -0.3101830225622285 GHz
#   readout_error: 0.06430000000000002
#   prob_meas0_prep1: 0.07720000000000005
#   prob_meas1_prep0: 0.0514
#   readout_length: 1400 ns
# Qubit 12:
#   T1: 413.42000561294793 us
#   T2: 122.60607413468891 us
#   frequency: 4.682914417211311 GHz
#   anharmonicity: -0.31013218093198514 GHz
#   readout_error: 0.019000000000000017
#   prob_meas0_prep1: 0.0162
#   prob_meas1_prep0: 0.02180000000000004
#   readout_length: 1400 ns
# Qubit 13:
#   T1: 259.448260364961 us
#   T2: 81.46546893481973 us
#   frequency: 4.729973557873034 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.0045999999999999375
#   prob_meas0_prep1: 0.005
#   prob_meas1_prep0: 0.0041999999999999815
#   readout_length: 1400 ns
# Qubit 14:
#   T1: 198.2198760732693 us
#   T2: 27.311813958780448 us
#   frequency: 4.740320635519167 GHz
#   anharmonicity: -0.31041215354308554 GHz
#   readout_error: 0.08860000000000001
#   prob_meas0_prep1: 0.09060000000000001
#   prob_meas1_prep0: 0.0866
#   readout_length: 1400 ns
# Qubit 15:
#   T1: 410.61405292185844 us
#   T2: 186.8093864456769 us
#   frequency: 4.669111935410979 GHz
#   anharmonicity: -0.31131069353860613 GHz
#   readout_error: 0.006000000000000005
#   prob_meas0_prep1: 0.0046000000000000485
#   prob_meas1_prep0: 0.0074
#   readout_length: 1400 ns
# Qubit 16:
#   T1: 7.717159571191255 us
#   T2: 332.4258176295806 us
#   frequency: 4.686079832907678 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.4387
#   prob_meas0_prep1: 0.4468
#   prob_meas1_prep0: 0.4306
#   readout_length: 1400 ns
# Qubit 17:
#   T1: 296.5694474751582 us
#   T2: 157.7565273998954 us
#   frequency: 4.8803468755301305 GHz
#   anharmonicity: -0.30671781899604517 GHz
#   readout_error: 0.02400000000000002
#   prob_meas0_prep1: 0.022399999999999975
#   prob_meas1_prep0: 0.0256
#   readout_length: 1400 ns
# Qubit 18:
#   T1: 266.10132768444004 us
#   T2: 101.07275436676208 us
#   frequency: 4.652949975703416 GHz
#   anharmonicity: -0.3108671975016885 GHz
#   readout_error: 0.0032999999999999696
#   prob_meas0_prep1: 0.0044
#   prob_meas1_prep0: 0.0021999999999999797
#   readout_length: 1400 ns
# Qubit 19:
#   T1: 337.9053323839055 us
#   T2: 134.94482456087255 us
#   frequency: 4.878872749843688 GHz
#   anharmonicity: -0.30848203027556864 GHz
#   readout_error: 0.02079999999999993
#   prob_meas0_prep1: 0.025000000000000022
#   prob_meas1_prep0: 0.0166
#   readout_length: 1400 ns
# Qubit 20:
#   T1: 391.4524077386018 us
#   T2: 205.7247004914799 us
#   frequency: 4.650853317561761 GHz
#   anharmonicity: -0.31198978446892245 GHz
#   readout_error: 0.018399999999999972
#   prob_meas0_prep1: 0.019
#   prob_meas1_prep0: 0.017800000000000038
#   readout_length: 1400 ns
# Qubit 21:
#   T1: 432.0998312242413 us
#   T2: 128.16788131081887 us
#   frequency: 4.568035299276529 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.01760000000000006
#   prob_meas0_prep1: 0.026599999999999957
#   prob_meas1_prep0: 0.0086
#   readout_length: 1400 ns
# Qubit 22:
#   T1: 378.19946865132385 us
#   T2: 250.0585308474554 us
#   frequency: 4.768023222558117 GHz
#   anharmonicity: -0.31007976218914873 GHz
#   readout_error: 0.07169999999999999
#   prob_meas0_prep1: 0.06940000000000002
#   prob_meas1_prep0: 0.074
#   readout_length: 1400 ns
# Qubit 23:
#   T1: 257.262536444385 us
#   T2: 11.118690500719044 us
#   frequency: 4.826019850874222 GHz
#   anharmonicity: -0.30896459047936825 GHz
#   readout_error: 0.060799999999999965
#   prob_meas0_prep1: 0.0464
#   prob_meas1_prep0: 0.0752
#   readout_length: 1400 ns
# Qubit 24:
#   T1: 256.5678311699833 us
#   T2: 51.60715094355107 us
#   frequency: 5.01978168206972 GHz
#   anharmonicity: -0.30541425054676014 GHz
#   readout_error: 0.22720000000000007
#   prob_meas0_prep1: 0.2208
#   prob_meas1_prep0: 0.2336
#   readout_length: 1400 ns
# Qubit 25:
#   T1: 192.825547400566 us
#   T2: 377.05983901549655 us
#   frequency: 4.84182639988296 GHz
#   anharmonicity: -0.3086237066221388 GHz
#   readout_error: 0.008899999999999908
#   prob_meas0_prep1: 0.0144
#   prob_meas1_prep0: 0.0033999999999999586
#   readout_length: 1400 ns
# Qubit 26:
#   T1: 332.80699461927026 us
#   T2: 20.058740972546225 us
#   frequency: 4.763747038137545 GHz
#   anharmonicity: -0.30945351875840205 GHz
#   readout_error: 0.00880000000000003
#   prob_meas0_prep1: 0.0096
#   prob_meas1_prep0: 0.008000000000000007
#   readout_length: 1400 ns
# Qubit 27:
#   T1: 395.57335829099503 us
#   T2: 176.30802996439678 us
#   frequency: 4.886544257004618 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.013299999999999979
#   prob_meas0_prep1: 0.012599999999999945
#   prob_meas1_prep0: 0.014
#   readout_length: 1400 ns
# Qubit 28:
#   T1: 217.61000323419464 us
#   T2: 34.07192134189335 us
#   frequency: 4.701263267983398 GHz
#   anharmonicity: -0.3099488275329216 GHz
#   readout_error: 0.02210000000000001
#   prob_meas0_prep1: 0.030200000000000005
#   prob_meas1_prep0: 0.014
#   readout_length: 1400 ns
# Qubit 29:
#   T1: 381.0147152423319 us
#   T2: 144.66935512045242 us
#   frequency: 4.744291189670616 GHz
#   anharmonicity: -0.31029420415842046 GHz
#   readout_error: 0.0043999999999999595
#   prob_meas0_prep1: 0.0046000000000000485
#   prob_meas1_prep0: 0.0042
#   readout_length: 1400 ns
# Qubit 30:
#   T1: 209.18659009942175 us
#   T2: 110.00644154406902 us
#   frequency: 4.922278270128195 GHz
#   anharmonicity: -0.30754311932801587 GHz
#   readout_error: 0.05190000000000006
#   prob_meas0_prep1: 0.05279999999999996
#   prob_meas1_prep0: 0.051
#   readout_length: 1400 ns
# Qubit 31:
#   T1: 267.3614369302985 us
#   T2: 264.8488198727889 us
#   frequency: 4.839772943127413 GHz
#   anharmonicity: -0.3084406817400851 GHz
#   readout_error: 0.008299999999999974
#   prob_meas0_prep1: 0.009000000000000008
#   prob_meas1_prep0: 0.0076
#   readout_length: 1400 ns
# Qubit 32:
#   T1: 310.3635211090382 us
#   T2: 163.29333045869438 us
#   frequency: 4.665159543291269 GHz
#   anharmonicity: -0.30998842157162854 GHz
#   readout_error: 0.009600000000000053
#   prob_meas0_prep1: 0.0132
#   prob_meas1_prep0: 0.006000000000000005
#   readout_length: 1400 ns
# Qubit 33:
#   T1: 141.87400518579614 us
#   T2: 16.266634521107992 us
#   frequency: 4.822699863226138 GHz
#   anharmonicity: -0.30430713299383766 GHz
#   readout_error: 0.008299999999999974
#   prob_meas0_prep1: 0.011399999999999966
#   prob_meas1_prep0: 0.0052
#   readout_length: 1400 ns
# Qubit 34:
#   T1: 264.2139343403637 us
#   T2: 22.87853926731856 us
#   frequency: 4.804587447821329 GHz
#   anharmonicity: -0.3082463291933374 GHz
#   readout_error: 0.09010000000000007
#   prob_meas0_prep1: 0.10040000000000004
#   prob_meas1_prep0: 0.0798
#   readout_length: 1400 ns
# Qubit 35:
#   T1: 146.90395218643917 us
#   T2: 198.19946917744258 us
#   frequency: 4.865270664855475 GHz
#   anharmonicity: -0.30823309297517987 GHz
#   readout_error: 0.026699999999999946
#   prob_meas0_prep1: 0.021599999999999953
#   prob_meas1_prep0: 0.0318
#   readout_length: 1400 ns
# Qubit 36:
#   T1: 453.3516285557407 us
#   T2: 222.7253981892604 us
#   frequency: 4.730251119485598 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.009199999999999986
#   prob_meas0_prep1: 0.01100000000000001
#   prob_meas1_prep0: 0.0074
#   readout_length: 1400 ns
# Qubit 37:
#   T1: 272.3815595384776 us
#   T2: 46.78795150653759 us
#   frequency: 4.936340961085208 GHz
#   anharmonicity: -0.3061260220579156 GHz
#   readout_error: 0.011900000000000022
#   prob_meas0_prep1: 0.0118
#   prob_meas1_prep0: 0.01200000000000001
#   readout_length: 1400 ns
# Qubit 38:
#   T1: 338.64954508705245 us
#   T2: 305.5172150458121 us
#   frequency: 4.81293495860712 GHz
#   anharmonicity: -0.3090441982328432 GHz
#   readout_error: 0.040100000000000025
#   prob_meas0_prep1: 0.0318
#   prob_meas1_prep0: 0.0484
#   readout_length: 1400 ns
# Qubit 39:
#   T1: 191.9029930506688 us
#   T2: 160.85596106782253 us
#   frequency: 4.699714321126858 GHz
#   anharmonicity: -0.3088854355334065 GHz
#   readout_error: 0.013500000000000068
#   prob_meas0_prep1: 0.0158
#   prob_meas1_prep0: 0.011199999999999988
#   readout_length: 1400 ns
# Qubit 40:
#   T1: 142.04087827212936 us
#   T2: 5.357551817006795 us
#   frequency: 4.892244043554185 GHz
#   anharmonicity: -0.30769778101539386 GHz
#   readout_error: 0.007400000000000073
#   prob_meas0_prep1: 0.00880000000000003
#   prob_meas1_prep0: 0.006
#   readout_length: 1400 ns
# Qubit 41:
#   T1: 159.89142168178353 us
#   T2: 105.81515331329607 us
#   frequency: 4.993942448280631 GHz
#   anharmonicity: -0.30666988456443384 GHz
#   readout_error: 0.034599999999999964
#   prob_meas0_prep1: 0.0372
#   prob_meas1_prep0: 0.03200000000000003
#   readout_length: 1400 ns
# Qubit 42:
#   T1: 243.83788515701795 us
#   T2: 5.833260801581486 us
#   frequency: 4.789235362844426 GHz
#   anharmonicity: -0.3092189965130921 GHz
#   readout_error: 0.007600000000000051
#   prob_meas0_prep1: 0.00880000000000003
#   prob_meas1_prep0: 0.0064
#   readout_length: 1400 ns
# Qubit 43:
#   T1: 350.7385963829092 us
#   T2: 108.34142953306922 us
#   frequency: 4.930803358750352 GHz
#   anharmonicity: -0.3075347075601374 GHz
#   readout_error: 0.019100000000000006
#   prob_meas0_prep1: 0.007800000000000029
#   prob_meas1_prep0: 0.0304
#   readout_length: 1400 ns
# Qubit 44:
#   T1: 266.02707822400373 us
#   T2: 21.96330739463175 us
#   frequency: 4.826598374116396 GHz
#   anharmonicity: -0.30878481550927667 GHz
#   readout_error: 0.01100000000000001
#   prob_meas0_prep1: 0.009
#   prob_meas1_prep0: 0.013000000000000012
#   readout_length: 1400 ns
# Qubit 45:
#   T1: 344.42794083625006 us
#   T2: 261.13153781299843 us
#   frequency: 4.924030130141617 GHz
#   anharmonicity: -0.3071097576761717 GHz
#   readout_error: 0.03859999999999997
#   prob_meas0_prep1: 0.0394
#   prob_meas1_prep0: 0.037799999999999945
#   readout_length: 1400 ns
# Qubit 46:
#   T1: 316.8276197197198 us
#   T2: 357.7046124856713 us
#   frequency: 4.853324170753301 GHz
#   anharmonicity: -0.30865419833002966 GHz
#   readout_error: 0.15480000000000005
#   prob_meas0_prep1: 0.16400000000000003
#   prob_meas1_prep0: 0.1456
#   readout_length: 1400 ns
# Qubit 47:
#   T1: 352.2341328913346 us
#   T2: 39.146728313371185 us
#   frequency: 4.797730683837709 GHz
#   anharmonicity: -0.3090685843813135 GHz
#   readout_error: 0.007900000000000018
#   prob_meas0_prep1: 0.0078
#   prob_meas1_prep0: 0.008000000000000007
#   readout_length: 1400 ns
# Qubit 48:
#   T1: 216.67315930954248 us
#   T2: 171.00614753818402 us
#   frequency: 4.8737441781228465 GHz
#   anharmonicity: -0.30796966519372043 GHz
#   readout_error: 0.02089999999999992
#   prob_meas0_prep1: 0.020399999999999974
#   prob_meas1_prep0: 0.0214
#   readout_length: 1400 ns
# Qubit 49:
#   T1: 143.39429787522974 us
#   T2: 53.95510061499028 us
#   frequency: 4.842913641700664 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.01079999999999992
#   prob_meas0_prep1: 0.0152
#   prob_meas1_prep0: 0.006399999999999961
#   readout_length: 1400 ns
# Qubit 50:
#   T1: 242.18065058130037 us
#   T2: 248.95584295269947 us
#   frequency: 5.003768421217287 GHz
#   anharmonicity: -0.30572919884522587 GHz
#   readout_error: 0.009700000000000042
#   prob_meas0_prep1: 0.010600000000000054
#   prob_meas1_prep0: 0.0088
#   readout_length: 1400 ns
# Qubit 51:
#   T1: 105.53153519621004 us
#   T2: 39.346521459053804 us
#   frequency: 4.931998861016234 GHz
#   anharmonicity: -0.30616136401130345 GHz
#   readout_error: 0.028999999999999915
#   prob_meas0_prep1: 0.0286
#   prob_meas1_prep0: 0.02939999999999998
#   readout_length: 1400 ns
# Qubit 52:
#   T1: 249.5452334767459 us
#   T2: 122.61579840343944 us
#   frequency: 4.977923059282584 GHz
#   anharmonicity: -0.30556697106388314 GHz
#   readout_error: 0.012900000000000023
#   prob_meas0_prep1: 0.01419999999999999
#   prob_meas1_prep0: 0.0116
#   readout_length: 1400 ns
# Qubit 53:
#   T1: 391.1247404594505 us
#   T2: 11.701607218604664 us
#   frequency: 4.848810764891353 GHz
#   anharmonicity: -0.3075268753502783 GHz
#   readout_error: 0.045599999999999974
#   prob_meas0_prep1: 0.0226
#   prob_meas1_prep0: 0.0686
#   readout_length: 1400 ns
# Qubit 54:
#   T1: 388.0673244282492 us
#   T2: 104.08020106563723 us
#   frequency: 4.8783558487492416 GHz
#   anharmonicity: -0.3069458254441859 GHz
#   readout_error: 0.036799999999999944
#   prob_meas0_prep1: 0.012399999999999967
#   prob_meas1_prep0: 0.0612
#   readout_length: 1400 ns
# Qubit 55:
#   T1: 298.5075856680919 us
#   T2: 115.51282829063624 us
#   frequency: 4.907306972284302 GHz
#   anharmonicity: -0.3073215185005289 GHz
#   readout_error: 0.0131
#   prob_meas0_prep1: 0.016599999999999948
#   prob_meas1_prep0: 0.0096
#   readout_length: 1400 ns
# Qubit 56:
#   T1: 104.77792188367033 us
#   T2: 81.1740457257179 us
#   frequency: 5.115806806748432 GHz
#   anharmonicity: -0.3040137770050246 GHz
#   readout_error: 0.021600000000000064
#   prob_meas0_prep1: 0.020000000000000018
#   prob_meas1_prep0: 0.0232
#   readout_length: 1400 ns
# Qubit 57:
#   T1: 237.79849101207097 us
#   T2: 155.6041222215386 us
#   frequency: 4.96946934852486 GHz
#   anharmonicity: -0.30548036357040764 GHz
#   readout_error: 0.007099999999999995
#   prob_meas0_prep1: 0.00539999999999996
#   prob_meas1_prep0: 0.0088
#   readout_length: 1400 ns
# Qubit 58:
#   T1: 431.2206679332121 us
#   T2: 170.74870094312513 us
#   frequency: 4.7373015551995605 GHz
#   anharmonicity: -0.3112562293028337 GHz
#   readout_error: 0.08850000000000002
#   prob_meas0_prep1: 0.08340000000000003
#   prob_meas1_prep0: 0.0936
#   readout_length: 1400 ns
# Qubit 59:
#   T1: 352.1341105700849 us
#   T2: 317.81200349301724 us
#   frequency: 4.901516818874679 GHz
#   anharmonicity: -0.3070516806225324 GHz
#   readout_error: 0.014699999999999935
#   prob_meas0_prep1: 0.015599999999999947
#   prob_meas1_prep0: 0.0138
#   readout_length: 1400 ns
# Qubit 60:
#   T1: 185.18513799812692 us
#   T2: 215.16583772876814 us
#   frequency: 4.937705951264602 GHz
#   anharmonicity: -0.3069452313257832 GHz
#   readout_error: 0.028200000000000003
#   prob_meas0_prep1: 0.02859999999999996
#   prob_meas1_prep0: 0.0278
#   readout_length: 1400 ns
# Qubit 61:
#   T1: 323.8517871609786 us
#   T2: 245.95364843735564 us
#   frequency: 4.8641761578146925 GHz
#   anharmonicity: -0.3089108825350579 GHz
#   readout_error: 0.30499999999999994
#   prob_meas0_prep1: 0.5
#   prob_meas1_prep0: 0.11
#   readout_length: 1400 ns
# Qubit 62:
#   T1: 422.3803658498534 us
#   T2: 241.51494073189613 us
#   frequency: 4.650871606410345 GHz
#   anharmonicity: -0.311771769762377 GHz
#   readout_error: 0.015900000000000025
#   prob_meas0_prep1: 0.024800000000000044
#   prob_meas1_prep0: 0.007
#   readout_length: 1400 ns
# Qubit 63:
#   T1: 372.7134721921852 us
#   T2: 192.78594098526207 us
#   frequency: 4.882153377580848 GHz
#   anharmonicity: -0.3077224207866349 GHz
#   readout_error: 0.005600000000000049
#   prob_meas0_prep1: 0.0054
#   prob_meas1_prep0: 0.005800000000000027
#   readout_length: 1400 ns
# Qubit 64:
#   T1: 128.13495947572275 us
#   T2: 92.8669183089716 us
#   frequency: 4.956159722392902 GHz
#   anharmonicity: -0.3072535034857098 GHz
#   readout_error: 0.007500000000000062
#   prob_meas0_prep1: 0.00880000000000003
#   prob_meas1_prep0: 0.0062
#   readout_length: 1400 ns
# Qubit 65:
#   T1: 368.59190294759094 us
#   T2: 197.75978278952547 us
#   frequency: 4.761276701821971 GHz
#   anharmonicity: -0.30847551722691047 GHz
#   readout_error: 0.015900000000000025
#   prob_meas0_prep1: 0.0148
#   prob_meas1_prep0: 0.017000000000000015
#   readout_length: 1400 ns
# Qubit 66:
#   T1: 235.56320164719793 us
#   T2: 22.580237124659945 us
#   frequency: 4.941249040185602 GHz
#   anharmonicity: -0.2827533936570362 GHz
#   readout_error: 0.06499999999999995
#   prob_meas0_prep1: 0.0552
#   prob_meas1_prep0: 0.07479999999999998
#   readout_length: 1400 ns
# Qubit 67:
#   T1: 245.05853153783403 us
#   T2: 106.71697984564122 us
#   frequency: 5.042694758086506 GHz
#   anharmonicity: -0.30553261906714385 GHz
#   readout_error: 0.04150000000000009
#   prob_meas0_prep1: 0.041
#   prob_meas1_prep0: 0.04200000000000004
#   readout_length: 1400 ns
# Qubit 68:
#   T1: 27.09172942755263 us
#   T2: 15.637387305621992 us
#   frequency: 5.128358357160639 GHz
#   anharmonicity: -0.3037249053723611 GHz
#   readout_error: 0.06020000000000003
#   prob_meas0_prep1: 0.0624
#   prob_meas1_prep0: 0.05800000000000005
#   readout_length: 1400 ns
# Qubit 69:
#   T1: 268.4620734861308 us
#   T2: 263.7974746788582 us
#   frequency: 5.073676601710252 GHz
#   anharmonicity: -0.303766875764741 GHz
#   readout_error: 0.01200000000000001
#   prob_meas0_prep1: 0.016
#   prob_meas1_prep0: 0.008000000000000007
#   readout_length: 1400 ns
# Qubit 70:
#   T1: 275.63365513493915 us
#   T2: 61.87991870349694 us
#   frequency: 4.87536340316715 GHz
#   anharmonicity: -0.30702041690984844 GHz
#   readout_error: 0.0826
#   prob_meas0_prep1: 0.07920000000000005
#   prob_meas1_prep0: 0.086
#   readout_length: 1400 ns
# Qubit 71:
#   T1: 363.652416595516 us
#   T2: 292.8898647090112 us
#   frequency: 4.826607564119188 GHz
#   anharmonicity: -0.3088117820479275 GHz
#   readout_error: 0.009199999999999986
#   prob_meas0_prep1: 0.011399999999999966
#   prob_meas1_prep0: 0.007
#   readout_length: 1400 ns
# Qubit 72:
#   T1: 324.56504552282246 us
#   T2: 19.363953579537537 us
#   frequency: 4.828030695943046 GHz
#   anharmonicity: -0.30825371875747126 GHz
#   readout_error: 0.018900000000000028
#   prob_meas0_prep1: 0.0198
#   prob_meas1_prep0: 0.018000000000000016
#   readout_length: 1400 ns
# Qubit 73:
#   T1: 183.5323556453175 us
#   T2: 169.25929987605346 us
#   frequency: 4.874052033192 GHz
#   anharmonicity: -0.3077336334044076 GHz
#   readout_error: 0.009199999999999986
#   prob_meas0_prep1: 0.012399999999999967
#   prob_meas1_prep0: 0.006
#   readout_length: 1400 ns
# Qubit 74:
#   T1: 359.6514596966031 us
#   T2: 217.7490619830447 us
#   frequency: 4.717506368735059 GHz
#   anharmonicity: -0.30924481406023596 GHz
#   readout_error: 0.03700000000000003
#   prob_meas0_prep1: 0.043200000000000016
#   prob_meas1_prep0: 0.0308
#   readout_length: 1400 ns
# Qubit 75:
#   T1: 261.2297163344566 us
#   T2: 83.93909130078451 us
#   frequency: 4.9150921989673595 GHz
#   anharmonicity: -0.3067429768189127 GHz
#   readout_error: 0.024499999999999966
#   prob_meas0_prep1: 0.02100000000000002
#   prob_meas1_prep0: 0.028
#   readout_length: 1400 ns
# Qubit 76:
#   T1: 278.31777962352623 us
#   T2: 207.54839432957837 us
#   frequency: 4.861175385235225 GHz
#   anharmonicity: -0.30806771434897606 GHz
#   readout_error: 0.013299999999999979
#   prob_meas0_prep1: 0.0172
#   prob_meas1_prep0: 0.009399999999999964
#   readout_length: 1400 ns
# Qubit 77:
#   T1: 324.7387862683042 us
#   T2: 195.1897125005983 us
#   frequency: 4.720508647240183 GHz
#   anharmonicity: -0.3106297524124092 GHz
#   readout_error: 0.1795
#   prob_meas0_prep1: 0.1572
#   prob_meas1_prep0: 0.2018
#   readout_length: 1400 ns
# Qubit 78:
#   T1: 334.9408626977926 us
#   T2: 305.76948206174126 us
#   frequency: 5.007267390812615 GHz
#   anharmonicity: -0.3075239620356322 GHz
#   readout_error: 0.4931
#   prob_meas0_prep1: 0.2966
#   prob_meas1_prep0: 0.6896
#   readout_length: 1400 ns
# Qubit 79:
#   T1: 325.0735378620135 us
#   T2: 332.5469600991613 us
#   frequency: 4.786364680885392 GHz
#   anharmonicity: -0.3096601397456687 GHz
#   readout_error: 0.01629999999999998
#   prob_meas0_prep1: 0.01639999999999997
#   prob_meas1_prep0: 0.0162
#   readout_length: 1400 ns
# Qubit 80:
#   T1: 200.02108686318522 us
#   T2: 74.45392570072289 us
#   frequency: 4.85085238778285 GHz
#   anharmonicity: -0.3079830471645371 GHz
#   readout_error: 0.09060000000000001
#   prob_meas0_prep1: 0.08320000000000005
#   prob_meas1_prep0: 0.098
#   readout_length: 1400 ns
# Qubit 81:
#   T1: 236.41381376176867 us
#   T2: 20.57189843958573 us
#   frequency: 5.001788017911833 GHz
#   anharmonicity: -0.28152033709593866 GHz
#   readout_error: 0.13339999999999996
#   prob_meas0_prep1: 0.14080000000000004
#   prob_meas1_prep0: 0.126
#   readout_length: 1400 ns
# Qubit 82:
#   T1: 292.6339796993711 us
#   T2: 19.061848539133415 us
#   frequency: 4.902330284983744 GHz
#   anharmonicity: -0.3073208151268094 GHz
#   readout_error: 0.0050000000000000044
#   prob_meas0_prep1: 0.0050000000000000044
#   prob_meas1_prep0: 0.005
#   readout_length: 1400 ns
# Qubit 83:
#   T1: 248.1083237801261 us
#   T2: 68.02084077613054 us
#   frequency: 5.03121252594649 GHz
#   anharmonicity: -0.3063243777084493 GHz
#   readout_error: 0.008399999999999963
#   prob_meas0_prep1: 0.009600000000000053
#   prob_meas1_prep0: 0.0072
#   readout_length: 1400 ns
# Qubit 84:
#   T1: 287.9938134340405 us
#   T2: 59.42965625732407 us
#   frequency: 4.894123389143901 GHz
#   anharmonicity: -0.3065902831656614 GHz
#   readout_error: 0.012900000000000023
#   prob_meas0_prep1: 0.01319999999999999
#   prob_meas1_prep0: 0.0126
#   readout_length: 1400 ns
# Qubit 85:
#   T1: 315.3435296407875 us
#   T2: 113.44141442136055 us
#   frequency: 4.990630041159421 GHz
#   anharmonicity: -0.3065800859785169 GHz
#   readout_error: 0.3083
#   prob_meas0_prep1: 0.29879999999999995
#   prob_meas1_prep0: 0.3178
#   readout_length: 1400 ns
# Qubit 86:
#   T1: 260.7264102012725 us
#   T2: 175.31790152604052 us
#   frequency: 4.943691999674723 GHz
#   anharmonicity: -0.3060679779681569 GHz
#   readout_error: 0.05600000000000005
#   prob_meas0_prep1: 0.052200000000000024
#   prob_meas1_prep0: 0.0598
#   readout_length: 1400 ns
# Qubit 87:
#   T1: 392.203308810315 us
#   T2: 104.03550384541792 us
#   frequency: 4.892891273254477 GHz
#   anharmonicity: -0.3071491684732496 GHz
#   readout_error: 0.04169999999999996
#   prob_meas0_prep1: 0.04459999999999997
#   prob_meas1_prep0: 0.0388
#   readout_length: 1400 ns
# Qubit 88:
#   T1: 100.2523576340869 us
#   T2: 98.71091640992303 us
#   frequency: 5.05255973295567 GHz
#   anharmonicity: -0.304960394436529 GHz
#   readout_error: 0.005700000000000038
#   prob_meas0_prep1: 0.007000000000000006
#   prob_meas1_prep0: 0.0044
#   readout_length: 1400 ns
# Qubit 89:
#   T1: 232.3843957225711 us
#   T2: 126.53552259292549 us
#   frequency: 4.92265323907595 GHz
#   anharmonicity: -0.3066542797849576 GHz
#   readout_error: 0.12080000000000002
#   prob_meas0_prep1: 0.11319999999999997
#   prob_meas1_prep0: 0.1284
#   readout_length: 1400 ns
# Qubit 90:
#   T1: 231.0134930796833 us
#   T2: 338.94986290334697 us
#   frequency: 4.983462400143876 GHz
#   anharmonicity: -0.30538470198551193 GHz
#   readout_error: 0.013600000000000056
#   prob_meas0_prep1: 0.0132
#   prob_meas1_prep0: 0.014000000000000012
#   readout_length: 1400 ns
# Qubit 91:
#   T1: 297.1027408855347 us
#   T2: 229.72156624434498 us
#   frequency: 4.869911218124197 GHz
#   anharmonicity: -0.3074936357613819 GHz
#   readout_error: 0.06889999999999996
#   prob_meas0_prep1: 0.07620000000000005
#   prob_meas1_prep0: 0.0616
#   readout_length: 1400 ns
# Qubit 92:
#   T1: 246.78609728134654 us
#   T2: 117.64685246033953 us
#   frequency: 4.943505884528082 GHz
#   anharmonicity: -0.30629552269162297 GHz
#   readout_error: 0.014599999999999946
#   prob_meas0_prep1: 0.0146
#   prob_meas1_prep0: 0.014599999999999946
#   readout_length: 1400 ns
# Qubit 93:
#   T1: 283.3020371667645 us
#   T2: 8.844690691203464 us
#   frequency: 4.6556568684362585 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.057800000000000074
#   prob_meas0_prep1: 0.03500000000000003
#   prob_meas1_prep0: 0.0806
#   readout_length: 1400 ns
# Qubit 94:
#   T1: 116.11642222847085 us
#   T2: 79.59599456863164 us
#   frequency: 4.892444579078986 GHz
#   anharmonicity: -0.3071648351996062 GHz
#   readout_error: 0.008399999999999963
#   prob_meas0_prep1: 0.009399999999999964
#   prob_meas1_prep0: 0.0074
#   readout_length: 1400 ns
# Qubit 95:
#   T1: 106.74334791262815 us
#   T2: 83.5015907567582 us
#   frequency: 4.805801101367754 GHz
#   anharmonicity: -0.30918254236870346 GHz
#   readout_error: 0.012800000000000034
#   prob_meas0_prep1: 0.016800000000000037
#   prob_meas1_prep0: 0.0088
#   readout_length: 1400 ns
# Qubit 96:
#   T1: 257.9962764434838 us
#   T2: 214.9781586042911 us
#   frequency: 4.904948184807577 GHz
#   anharmonicity: -0.3075517924661106 GHz
#   readout_error: 0.06980000000000008
#   prob_meas0_prep1: 0.06040000000000001
#   prob_meas1_prep0: 0.0792
#   readout_length: 1400 ns
# Qubit 97:
#   T1: 302.46077119082037 us
#   T2: 206.08882669209748 us
#   frequency: 4.827985399268623 GHz
#   anharmonicity: -0.3077086218539215 GHz
#   readout_error: 0.02429999999999999
#   prob_meas0_prep1: 0.039000000000000035
#   prob_meas1_prep0: 0.0096
#   readout_length: 1400 ns
# Qubit 98:
#   T1: 380.2612317066345 us
#   T2: 15.558248088729046 us
#   frequency: 4.931867452348257 GHz
#   anharmonicity: -0.3071662914424166 GHz
#   readout_error: 0.009600000000000053
#   prob_meas0_prep1: 0.008
#   prob_meas1_prep0: 0.011199999999999988
#   readout_length: 1400 ns
# Qubit 99:
#   T1: 292.3789177913725 us
#   T2: 164.83167192859486 us
#   frequency: 4.847705716865722 GHz
#   anharmonicity: -0.3073928429952756 GHz
#   readout_error: 0.0252
#   prob_meas0_prep1: 0.0124
#   prob_meas1_prep0: 0.038000000000000034
#   readout_length: 1400 ns
# Qubit 100:
#   T1: 189.00563362822365 us
#   T2: 206.45932179924054 us
#   frequency: 5.038239407969292 GHz
#   anharmonicity: -0.305216444060978 GHz
#   readout_error: 0.01529999999999998
#   prob_meas0_prep1: 0.015000000000000013
#   prob_meas1_prep0: 0.0156
#   readout_length: 1400 ns
# Qubit 101:
#   T1: 367.56229332966336 us
#   T2: 183.43503041788435 us
#   frequency: 4.786652718713693 GHz
#   anharmonicity: -0.30859022081829135 GHz
#   readout_error: 0.010000000000000009
#   prob_meas0_prep1: 0.0104
#   prob_meas1_prep0: 0.009600000000000053
#   readout_length: 1400 ns
# Qubit 102:
#   T1: 406.0321681441666 us
#   T2: 248.79666515846145 us
#   frequency: 4.864149412985296 GHz
#   anharmonicity: -0.3079078250736739 GHz
#   readout_error: 0.014699999999999935
#   prob_meas0_prep1: 0.015599999999999947
#   prob_meas1_prep0: 0.0138
#   readout_length: 1400 ns
# Qubit 103:
#   T1: 265.0268162810025 us
#   T2: 138.48116338292783 us
#   frequency: 4.947655369696464 GHz
#   anharmonicity: -0.3061106856768402 GHz
#   readout_error: 0.010599999999999943
#   prob_meas0_prep1: 0.0104
#   prob_meas1_prep0: 0.010800000000000032
#   readout_length: 1400 ns
# Qubit 104:
#   T1: 366.8859079056976 us
#   T2: 158.56469117295904 us
#   frequency: 4.823256328860357 GHz
#   anharmonicity: -0.30887389224640077 GHz
#   readout_error: 0.06833333333333336
#   prob_meas0_prep1: 0.023333333333333334
#   prob_meas1_prep0: 0.11333333333333329
#   readout_length: 1400 ns
# Qubit 105:
#   T1: 264.3889281501928 us
#   T2: 197.3586737787162 us
#   frequency: 4.923680512106951 GHz
#   anharmonicity: -0.30744604347870486 GHz
#   readout_error: 0.05800000000000005
#   prob_meas0_prep1: 0.06279999999999997
#   prob_meas1_prep0: 0.0532
#   readout_length: 1400 ns
# Qubit 106:
#   T1: 33.118004991713164 us
#   T2: 127.2276491792076 us
#   frequency: 4.833835391366063 GHz
#   anharmonicity: 0 GHz
#   readout_error: 0.20189999999999997
#   prob_meas0_prep1: 0.39039999999999997
#   prob_meas1_prep0: 0.0134
#   readout_length: 1400 ns
# Qubit 107:
#   T1: 350.0164777192235 us
#   T2: 285.2919671534697 us
#   frequency: 4.737137154868877 GHz
#   anharmonicity: -0.3092323185160615 GHz
#   readout_error: 0.028200000000000003
#   prob_meas0_prep1: 0.0224
#   prob_meas1_prep0: 0.03400000000000003
#   readout_length: 1400 ns
# Qubit 108:
#   T1: 258.17428648345293 us
#   T2: 277.83495877183225 us
#   frequency: 4.848579888496308 GHz
#   anharmonicity: -0.30758756009823 GHz
#   readout_error: 0.020299999999999985
#   prob_meas0_prep1: 0.029
#   prob_meas1_prep0: 0.011600000000000055
#   readout_length: 1400 ns
# Qubit 109:
#   T1: 223.9970031152806 us
#   T2: 62.55282655686665 us
#   frequency: 4.8162774141497895 GHz
#   anharmonicity: -0.3076224851395677 GHz
#   readout_error: 0.07379999999999998
#   prob_meas0_prep1: 0.0668
#   prob_meas1_prep0: 0.08079999999999998
#   readout_length: 1400 ns
# Qubit 110:
#   T1: 301.7251291504747 us
#   T2: 43.15175072806296 us
#   frequency: 4.960863447426725 GHz
#   anharmonicity: -0.30654326919776725 GHz
#   readout_error: 0.1139
#   prob_meas0_prep1: 0.091
#   prob_meas1_prep0: 0.13680000000000003
#   readout_length: 1400 ns
# Qubit 111:
#   T1: 154.83516059653198 us
#   T2: 7.309000420990417 us
#   frequency: 4.7717701752341455 GHz
#   anharmonicity: -0.27459033814679856 GHz
#   readout_error: 0.07833333333333337
#   prob_meas0_prep1: 0.08999999999999997
#   prob_meas1_prep0: 0.06666666666666667
#   readout_length: 1400 ns
# Qubit 112:
#   T1: 447.1126679687988 us
#   T2: 197.60133275387193 us
#   frequency: 4.75801839287122 GHz
#   anharmonicity: -0.30947821505202616 GHz
#   readout_error: 0.013000000000000012
#   prob_meas0_prep1: 0.013399999999999967
#   prob_meas1_prep0: 0.0126
#   readout_length: 1400 ns
# Qubit 113:
#   T1: 342.21929846972387 us
#   T2: 276.97465934533705 us
#   frequency: 4.878202730545551 GHz
#   anharmonicity: -0.3074886323823703 GHz
#   readout_error: 0.020399999999999974
#   prob_meas0_prep1: 0.023
#   prob_meas1_prep0: 0.017800000000000038
#   readout_length: 1400 ns
# Qubit 114:
#   T1: 173.46968445451367 us
#   T2: 84.66079602995356 us
#   frequency: 4.956596946173287 GHz
#   anharmonicity: -0.3061319026371913 GHz
#   readout_error: 0.0131
#   prob_meas0_prep1: 0.01639999999999997
#   prob_meas1_prep0: 0.0098
#   readout_length: 1400 ns
# Qubit 115:
#   T1: 287.0699487533087 us
#   T2: 193.6075989857154 us
#   frequency: 4.8612610584579725 GHz
#   anharmonicity: -0.3074906249301007 GHz
#   readout_error: 0.01330000000000009
#   prob_meas0_prep1: 0.0106
#   prob_meas1_prep0: 0.016000000000000014
#   readout_length: 1400 ns
# Qubit 116:
#   T1: 225.92135171213212 us
#   T2: 280.290564422259 us
#   frequency: 4.925793730533574 GHz
#   anharmonicity: -0.30611575224355886 GHz
#   readout_error: 0.03639999999999999
#   prob_meas0_prep1: 0.03820000000000001
#   prob_meas1_prep0: 0.0346
#   readout_length: 1400 ns
# Qubit 117:
#   T1: 285.4001891800765 us
#   T2: 169.00816805038772 us
#   frequency: 4.826801947562268 GHz
#   anharmonicity: -0.307647357570589 GHz
#   readout_error: 0.1038
#   prob_meas0_prep1: 0.09860000000000002
#   prob_meas1_prep0: 0.109
#   readout_length: 1400 ns
# Qubit 118:
#   T1: 172.89802607655463 us
#   T2: 25.62329017341288 us
#   frequency: 4.917663974275936 GHz
#   anharmonicity: -0.2837864146340105 GHz
#   readout_error: 0.036799999999999944
#   prob_meas0_prep1: 0.015599999999999947
#   prob_meas1_prep0: 0.058
#   readout_length: 1400 ns
# Qubit 119:
#   T1: 422.6004584725604 us
#   T2: 254.65327404983586 us
#   frequency: 4.684277496916036 GHz
#   anharmonicity: -0.31156380867939937 GHz
#   readout_error: 0.00550000000000006
#   prob_meas0_prep1: 0.005800000000000027
#   prob_meas1_prep0: 0.0052
#   readout_length: 1400 ns
# Qubit 120:
#   T1: 327.7130439872379 us
#   T2: 193.47223192278318 us
#   frequency: 4.871214021772473 GHz
#   anharmonicity: -0.3070908094384928 GHz
#   readout_error: 0.03869999999999996
#   prob_meas0_prep1: 0.0346
#   prob_meas1_prep0: 0.04279999999999995
#   readout_length: 1400 ns
# Qubit 121:
#   T1: 219.41492490253253 us
#   T2: 94.93467469488945 us
#   frequency: 5.069358500264836 GHz
#   anharmonicity: -0.3048890858354447 GHz
#   readout_error: 0.02279999999999993
#   prob_meas0_prep1: 0.02739999999999998
#   prob_meas1_prep0: 0.0182
#   readout_length: 1400 ns
# Qubit 122:
#   T1: 389.4547036039526 us
#   T2: 267.0804422062836 us
#   frequency: 4.88044690301713 GHz
#   anharmonicity: -0.30676936019588796 GHz
#   readout_error: 0.01100000000000001
#   prob_meas0_prep1: 0.014000000000000012
#   prob_meas1_prep0: 0.008
#   readout_length: 1400 ns
# Qubit 123:
#   T1: 252.79797289029227 us
#   T2: 281.3090132581551 us
#   frequency: 5.058569760837234 GHz
#   anharmonicity: -0.3044524112728942 GHz
#   readout_error: 0.013399999999999967
#   prob_meas0_prep1: 0.0074
#   prob_meas1_prep0: 0.019399999999999973
#   readout_length: 1400 ns
# Qubit 124:
#   T1: 344.4702611600692 us
#   T2: 289.6329900699176 us
#   frequency: 4.846352852134355 GHz
#   anharmonicity: -0.30693185637104947 GHz
#   readout_error: 0.02400000000000002
#   prob_meas0_prep1: 0.0262
#   prob_meas1_prep0: 0.02180000000000004
#   readout_length: 1400 ns
# Qubit 125:
#   T1: 231.1019737174457 us
#   T2: 193.87477845495354 us
#   frequency: 5.042870730366642 GHz
#   anharmonicity: -0.30464499216097907 GHz
#   readout_error: 0.045599999999999974
#   prob_meas0_prep1: 0.04179999999999995
#   prob_meas1_prep0: 0.0494
#   readout_length: 1400 ns
# Qubit 126:
#   T1: 263.755234638281 us
#   T2: 121.56688425662715 us
#   frequency: 4.99330688720385 GHz
#   anharmonicity: -0.30499159890695277 GHz
#   readout_error: 0.014699999999999935
#   prob_meas0_prep1: 0.0118
#   prob_meas1_prep0: 0.01759999999999995
#   readout_length: 1400 ns

# %%
# Criar um modelo de ruído a partir do backend selecionado
noise_model = NoiseModel.from_backend(backend)

# %%
# Usar o AerSimulator com o modelo de ruído
simulator = AerSimulator(method='density_matrix', noise_model=noise_model)

# %%
# Criar um circuito quântico simples (Estados de Bell)
qc = QuantumCircuit(2)
qc.h(0)  # Aplicar porta Hadamard no qubit 0
qc.cx(0, 1)  # Aplicar porta CNOT com o qubit 0 como controle e qubit 1 como alvo
qc.measure_all()  # Medir todos os qubits

# %%
# Transpilar o circuito para o simulador com ruído
transpiled_qc = transpile(qc, backend=simulator)

# %%
# Executar o circuito no simulador com ruído
simulation = simulator.run(transpiled_qc, shots=10000)

# %%
# Obter e imprimir os resultados da simulação
result = simulation.result()
counts = result.get_counts()
print("Contagens resultantes da simulação com ruído:", counts)
# Out:
# Contagens resultantes da simulação com ruído: {'01': 156, '10': 135, '00': 4869, '11': 4840}

# %%
# Olha só!!! Em um circuito quântico perfeito, sem ruído, só teríamos estados 00 e 11 (estados de Bell), o que não acontece em um circuito ruidoso
